# %%
# Dependencies and Setup
import pandas as pd
import json
import numpy as np

# SQL Alchemy Dependencies
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Read movie_metadata.csv into movie_df
movie_df = pd.read_csv("Resources/movie_metadata.csv")
movie_df.rename(columns={'movie_title':'title'}, inplace=True)

# %%
# Read all_script.csv into script_df
script_df = pd.read_csv("Resources/updated_all_script.csv")
script_df
# Out:
#                            title  Swear_Count  Fuck_Count  Shit_Count  \
# 0     10 Things I Hate About You           15           3           6
# 1                             12            2           2           0
# 2                 12 and Holding           21          10          10
# 3                     12 Monkeys           17          11           4
# 4               12 Years a Slave            1           0           0
# ...                          ...          ...         ...         ...
# 1206             You've Got Mail            9           4           4
# 1207             Youth in Revolt            6           2           4
# 1208            Zero Dark Thirty           44          41           2
# 1209                  Zerophilia           18          14           4
# 1210                    Zootopia            0           0           0
#
#       Bitch_Count  Cunt_Count Profanity
# 0               6           0      TRUE
# 1               0           0      TRUE
# 2               1           0      TRUE
# 3               2           0      TRUE
# 4               1           0      TRUE
# ...           ...         ...       ...
# 1206            1           0      TRUE
# 1207            0           0      TRUE
# 1208            1           0      TRUE
# 1209            0           0      TRUE
# 1210            0           0        []
#
# [1211 rows x 7 columns]

# %%
movie_df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# title                         object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# Select
cleaned_movie_df = movie_df[["title","director_name","genres","duration","title_year","budget","content_rating","imdb_score","gross","actor_1_name","actor_2_name","actor_3_name","facenumber_in_poster","cast_total_facebook_likes","imdb_score","plot_keywords","country"]]
cleaned_movie_df
# Out:
#                                                   title      director_name  \
# 0                                                Avatar      James Cameron
# 1              Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                               Spectre         Sam Mendes
# 3                                 The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                            Signed Sealed Delivered        Scott Smith
# 5039                          The Following                            NaN
# 5040                               A Plague So Pleasant   Benjamin Roberds
# 5041                                   Shanghai Calling        Daniel Hsia
# 5042                                  My Date with Drew           Jon Gunn
#
#                                genres  duration  title_year       budget  \
# 0     Action|Adventure|Fantasy|Sci-Fi     178.0      2009.0  237000000.0
# 1            Action|Adventure|Fantasy     169.0      2007.0  300000000.0
# 2           Action|Adventure|Thriller     148.0      2015.0  245000000.0
# 3                     Action|Thriller     164.0      2012.0  250000000.0
# 4                         Documentary       NaN         NaN          NaN
# ...                               ...       ...         ...          ...
# 5038                     Comedy|Drama      87.0      2013.0          NaN
# 5039     Crime|Drama|Mystery|Thriller      43.0         NaN          NaN
# 5040            Drama|Horror|Thriller      76.0      2013.0       1400.0
# 5041             Comedy|Drama|Romance     100.0      2012.0          NaN
# 5042                      Documentary      90.0      2004.0       1100.0
#
#      content_rating  imdb_score        gross     actor_1_name  \
# 0             PG-13         7.9  760505847.0      CCH Pounder
# 1             PG-13         7.1  309404152.0      Johnny Depp
# 2             PG-13         6.8  200074175.0  Christoph Waltz
# 3             PG-13         8.5  448130642.0        Tom Hardy
# 4               NaN         7.1          NaN      Doug Walker
# ...             ...         ...          ...              ...
# 5038            NaN         7.7          NaN      Eric Mabius
# 5039          TV-14         7.5          NaN      Natalie Zea
# 5040            NaN         6.3          NaN      Eva Boehnke
# 5041          PG-13         6.3      10443.0        Alan Ruck
# 5042             PG         6.6      85222.0      John August
#
#           actor_2_name          actor_3_name  facenumber_in_poster  \
# 0     Joel David Moore             Wes Studi                   0.0
# 1        Orlando Bloom        Jack Davenport                   0.0
# 2         Rory Kinnear      Stephanie Sigman                   1.0
# 3       Christian Bale  Joseph Gordon-Levitt                   0.0
# 4           Rob Walker                   NaN                   0.0
# ...                ...                   ...                   ...
# 5038     Daphne Zuniga          Crystal Lowe                   2.0
# 5039     Valorie Curry         Sam Underwood                   1.0
# 5040     Maxwell Moody        David Chandler                   0.0
# 5041     Daniel Henney           Eliza Coupe                   5.0
# 5042  Brian Herzlinger              Jon Gunn                   0.0
#
#       cast_total_facebook_likes  imdb_score  \
# 0                          4834         7.9
# 1                         48350         7.1
# 2                         11700         6.8
# 3                        106759         8.5
# 4                           143         7.1
# ...                         ...         ...
# 5038                       2283         7.7
# 5039                       1753         7.5
# 5040                          0         6.3
# 5041                       2386         6.3
# 5042                        163         6.6
#
#                                           plot_keywords country
# 0                avatar|future|marine|native|paraplegic     USA
# 1     goddess|marriage ceremony|marriage proposal|pi...     USA
# 2                   bomb|espionage|sequel|spy|terrorist      UK
# 3     deception|imprisonment|lawlessness|police offi...     USA
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 5038             fraud|postal worker|prison|theft|trial  Canada
# 5039       cult|fbi|hideout|prison escape|serial killer     USA
# 5040                                                NaN     USA
# 5041                                                NaN     USA
# 5042  actress name in title|crush|date|four word tit...     USA
#
# [5043 rows x 17 columns]

# %%
cleaned_movie_df.genres = cleaned_movie_df.genres.str.split('|')
# Out:
# C:\Users\kaoti\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
cleaned_movie_df.plot_keywords = cleaned_movie_df.plot_keywords.str.split('|')

# %%
cleaned_movie_df['profit'] = cleaned_movie_df['gross']- cleaned_movie_df['budget']
# Out:
# <ipython-input-9-19c34b7262b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_movie_df['profit'] = cleaned_movie_df['gross']- cleaned_movie_df['budget']

# %%
comparison_column = np.where(cleaned_movie_df["budget"] <= cleaned_movie_df["gross"], True, False)

# %%
cleaned_movie_df['breakeven'] = comparison_column
# Out:
# <ipython-input-19-5b19a571f6c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_movie_df['breakeven'] = comparison_column

# %%
cleaned_movie_df = cleaned_movie_df.drop_duplicates(subset=['title'])

# %%
cleaned_movie_df
# Out:
#                                                   title      director_name  \
# 0                                                Avatar      James Cameron
# 1              Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                               Spectre         Sam Mendes
# 3                                 The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                            Signed Sealed Delivered        Scott Smith
# 5039                          The Following                            NaN
# 5040                               A Plague So Pleasant   Benjamin Roberds
# 5041                                   Shanghai Calling        Daniel Hsia
# 5042                                  My Date with Drew           Jon Gunn
#
#                                     genres  duration  title_year       budget  \
# 0     [Action, Adventure, Fantasy, Sci-Fi]     178.0      2009.0  237000000.0
# 1             [Action, Adventure, Fantasy]     169.0      2007.0  300000000.0
# 2            [Action, Adventure, Thriller]     148.0      2015.0  245000000.0
# 3                       [Action, Thriller]     164.0      2012.0  250000000.0
# 4                            [Documentary]       NaN         NaN          NaN
# ...                                    ...       ...         ...          ...
# 5038                       [Comedy, Drama]      87.0      2013.0          NaN
# 5039     [Crime, Drama, Mystery, Thriller]      43.0         NaN          NaN
# 5040             [Drama, Horror, Thriller]      76.0      2013.0       1400.0
# 5041              [Comedy, Drama, Romance]     100.0      2012.0          NaN
# 5042                         [Documentary]      90.0      2004.0       1100.0
#
#      content_rating  imdb_score        gross     actor_1_name  \
# 0             PG-13         7.9  760505847.0      CCH Pounder
# 1             PG-13         7.1  309404152.0      Johnny Depp
# 2             PG-13         6.8  200074175.0  Christoph Waltz
# 3             PG-13         8.5  448130642.0        Tom Hardy
# 4               NaN         7.1          NaN      Doug Walker
# ...             ...         ...          ...              ...
# 5038            NaN         7.7          NaN      Eric Mabius
# 5039          TV-14         7.5          NaN      Natalie Zea
# 5040            NaN         6.3          NaN      Eva Boehnke
# 5041          PG-13         6.3      10443.0        Alan Ruck
# 5042             PG         6.6      85222.0      John August
#
#           actor_2_name          actor_3_name  facenumber_in_poster  \
# 0     Joel David Moore             Wes Studi                   0.0
# 1        Orlando Bloom        Jack Davenport                   0.0
# 2         Rory Kinnear      Stephanie Sigman                   1.0
# 3       Christian Bale  Joseph Gordon-Levitt                   0.0
# 4           Rob Walker                   NaN                   0.0
# ...                ...                   ...                   ...
# 5038     Daphne Zuniga          Crystal Lowe                   2.0
# 5039     Valorie Curry         Sam Underwood                   1.0
# 5040     Maxwell Moody        David Chandler                   0.0
# 5041     Daniel Henney           Eliza Coupe                   5.0
# 5042  Brian Herzlinger              Jon Gunn                   0.0
#
#       cast_total_facebook_likes  imdb_score  \
# 0                          4834         7.9
# 1                         48350         7.1
# 2                         11700         6.8
# 3                        106759         8.5
# 4                           143         7.1
# ...                         ...         ...
# 5038                       2283         7.7
# 5039                       1753         7.5
# 5040                          0         6.3
# 5041                       2386         6.3
# 5042                        163         6.6
#
#                                           plot_keywords country       profit  \
# 0          [avatar, future, marine, native, paraplegic]     USA  523505847.0
# 1     [goddess, marriage ceremony, marriage proposal...     USA    9404152.0
# 2             [bomb, espionage, sequel, spy, terrorist]      UK  -44925825.0
# 3     [deception, imprisonment, lawlessness, police ...     USA  198130642.0
# 4                                                   NaN     NaN          NaN
# ...                                                 ...     ...          ...
# 5038       [fraud, postal worker, prison, theft, trial]  Canada          NaN
# 5039  [cult, fbi, hideout, prison escape, serial kil...     USA          NaN
# 5040                                                NaN     USA          NaN
# 5041                                                NaN     USA          NaN
# 5042  [actress name in title, crush, date, four word...     USA      84122.0
#
#       breakeven
# 0          True
# 1          True
# 2         False
# 3          True
# 4         False
# ...         ...
# 5038      False
# 5039      False
# 5040      False
# 5041      False
# 5042       True
#
# [4917 rows x 19 columns]

# %%
cleaned_movie_df['title'].astype("string")
# Out:
# 0                                                  Avatar
# 1                Pirates of the Caribbean: At World's End
# 2                                                 Spectre
# 3                                   The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                              Signed Sealed Delivered
# 5039                            The Following
# 5040                                 A Plague So Pleasant
# 5041                                     Shanghai Calling
# 5042                                    My Date with Drew
# Name: title, Length: 4917, dtype: string

# %%
script_df['title'].astype("string")
# Out:
# 0       10 Things I Hate About You
# 1                               12
# 2                   12 and Holding
# 3                       12 Monkeys
# 4                 12 Years a Slave
#                    ...
# 1206               You've Got Mail
# 1207               Youth in Revolt
# 1208              Zero Dark Thirty
# 1209                    Zerophilia
# 1210                      Zootopia
# Name: title, Length: 1211, dtype: string

# %%
script_df.dtypes
# Out:
# title          object
# Swear_Count     int64
# Fuck_Count      int64
# Shit_Count      int64
# Bitch_Count     int64
# Cunt_Count      int64
# Profanity      object
# dtype: object

# %%
movie_swear_df = pd.merge(cleaned_movie_df,script_df,how='inner',on='title')
#movie_df.join(script_df, on='title',how='outer')

movie_swear_df
# Out:
#                                           title      director_name  \
# 0                                        Avatar      James Cameron
# 1                         The Dark Knight Rises  Christopher Nolan
# 2        Harry Potter and the Half-Blood Prince        David Yates
# 3    Pirates of the Caribbean: Dead Man's Chest     Gore Verbinski
# 4                                  The Avengers        Joss Whedon
# ..                                          ...                ...
# 741                                        Cube    Vincenzo Natali
# 742                                    Swingers         Doug Liman
# 743                                          Pi   Darren Aronofsky
# 744                                      Clerks        Kevin Smith
# 745                                 El Mariachi   Robert Rodriguez
#
#                                         genres  duration  title_year  \
# 0         [Action, Adventure, Fantasy, Sci-Fi]     178.0      2009.0
# 1                           [Action, Thriller]     164.0      2012.0
# 2        [Adventure, Family, Fantasy, Mystery]     153.0      2009.0
# 3                 [Action, Adventure, Fantasy]     151.0      2006.0
# 4                  [Action, Adventure, Sci-Fi]     173.0      2012.0
# ..                                         ...       ...         ...
# 741                [Mystery, Sci-Fi, Thriller]      90.0      1997.0
# 742                            [Comedy, Drama]      96.0      1996.0
# 743                 [Drama, Mystery, Thriller]      84.0      1998.0
# 744                                   [Comedy]     102.0      1994.0
# 745  [Action, Crime, Drama, Romance, Thriller]      81.0      1992.0
#
#           budget content_rating  imdb_score        gross     actor_1_name  \
# 0    237000000.0          PG-13         7.9  760505847.0      CCH Pounder
# 1    250000000.0          PG-13         8.5  448130642.0        Tom Hardy
# 2    250000000.0             PG         7.5  301956980.0     Alan Rickman
# 3    225000000.0          PG-13         7.3  423032628.0      Johnny Depp
# 4    220000000.0          PG-13         8.1  623279547.0  Chris Hemsworth
# ..           ...            ...         ...          ...              ...
# 741     365000.0              R         7.3     489220.0    David Hewlett
# 742     200000.0              R         7.4    4505922.0      Jon Favreau
# 743      60000.0              R         7.5    3216970.0    Mark Margolis
# 744     230000.0              R         7.8    3151130.0      Jason Mewes
# 745       7000.0              R         6.9    2040920.0  Carlos Gallardo
#
#      ...                                      plot_keywords country  \
# 0    ...       [avatar, future, marine, native, paraplegic]     USA
# 1    ...  [deception, imprisonment, lawlessness, police ...     USA
# 2    ...             [blood, book, love, potion, professor]      UK
# 3    ...  [box office hit, giant squid, heart, liar's di...     USA
# 4    ...  [alien invasion, assassin, battle, iron man, s...     USA
# ..   ...                                                ...     ...
# 741  ...         [escape, labyrinth, maze, red light, trap]  Canada
# 742  ...  [actor, black panties, cult film, friend, upsk...     USA
# 743  ...  [mathematician, nature, numbers, pattern, usin...     USA
# 744  ...        [clerk, friend, hockey, video, video store]     USA
# 745  ...           [assassin, death, guitar, gun, mariachi]     USA
#
#           profit  breakeven  Swear_Count Fuck_Count Shit_Count  Bitch_Count  \
# 0    523505847.0       True           18          1         11            6
# 1    198130642.0       True            2          0          0            2
# 2     51956980.0       True            0          0          0            0
# 3    198032628.0       True            0          0          0            0
# 4    403279547.0       True           24         13         10            1
# ..           ...        ...          ...        ...        ...          ...
# 741     124220.0       True           26         24          1            1
# 742    4305922.0       True           52         12         20           20
# 743    3156970.0       True           13         10          3            0
# 744    2921130.0       True          118         78         35            2
# 745    2033920.0       True            0          0          0            0
#
#      Cunt_Count  Profanity
# 0             0       TRUE
# 1             0       TRUE
# 2             0         []
# 3             0         []
# 4             0       TRUE
# ..          ...        ...
# 741           0       TRUE
# 742           0       TRUE
# 743           0       TRUE
# 744           3       TRUE
# 745           0         []
#
# [746 rows x 25 columns]

# %%
movie_swear_df.to_csv("Resources/movie_swear.csv")

# %%
movie_swear_df.head()
# Out:
#                                         title      director_name  \
# 0                                      Avatar      James Cameron
# 1                       The Dark Knight Rises  Christopher Nolan
# 2      Harry Potter and the Half-Blood Prince        David Yates
# 3  Pirates of the Caribbean: Dead Man's Chest     Gore Verbinski
# 4                                The Avengers        Joss Whedon
#
#                                   genres  duration  title_year       budget  \
# 0   [Action, Adventure, Fantasy, Sci-Fi]     178.0      2009.0  237000000.0
# 1                     [Action, Thriller]     164.0      2012.0  250000000.0
# 2  [Adventure, Family, Fantasy, Mystery]     153.0      2009.0  250000000.0
# 3           [Action, Adventure, Fantasy]     151.0      2006.0  225000000.0
# 4            [Action, Adventure, Sci-Fi]     173.0      2012.0  220000000.0
#
#   content_rating  imdb_score        gross     actor_1_name  ...  \
# 0          PG-13         7.9  760505847.0      CCH Pounder  ...
# 1          PG-13         8.5  448130642.0        Tom Hardy  ...
# 2             PG         7.5  301956980.0     Alan Rickman  ...
# 3          PG-13         7.3  423032628.0      Johnny Depp  ...
# 4          PG-13         8.1  623279547.0  Chris Hemsworth  ...
#
#                                        plot_keywords country       profit  \
# 0       [avatar, future, marine, native, paraplegic]     USA  523505847.0
# 1  [deception, imprisonment, lawlessness, police ...     USA  198130642.0
# 2             [blood, book, love, potion, professor]      UK   51956980.0
# 3  [box office hit, giant squid, heart, liar's di...     USA  198032628.0
# 4  [alien invasion, assassin, battle, iron man, s...     USA  403279547.0
#
#    breakeven  Swear_Count Fuck_Count Shit_Count  Bitch_Count  Cunt_Count  \
# 0       True           18          1         11            6           0
# 1       True            2          0          0            2           0
# 2       True            0          0          0            0           0
# 3       True            0          0          0            0           0
# 4       True           24         13         10            1           0
#
#    Profanity
# 0       TRUE
# 1       TRUE
# 2         []
# 3         []
# 4       TRUE
#
# [5 rows x 25 columns]

# %%
# Create database connection and load quake.df into database
rds_connection_string = "postgres:postgres@localhost:5432/movie_swear_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
cleaned_movie_df.to_sql(name='movie',con=engine, if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-28-95e9e415cca5> in <module>
# ----> 1 cleaned_movie_df.to_sql(name='movie',con=engine, if_exists='replace',index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     719
#     720     def create(self):
# --> 721         if self.exists():
#     722             if self.if_exists == "fail":
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     706
#     707     def exists(self):
# --> 708         return self.pd_sql.has_table(self.name, self.schema)
#     709
#     710     def sql_schema(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1428
#    1429     def has_table(self, name, schema=None):
# -> 1430         return self.connectable.run_callable(
#    1431             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1432         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
script_df.to_sql(name='script',con=engine, if_exists='replace',index=False)

# %%
movie_swear_df.to_sql(name='movie_swear',con=engine, if_exists='replace',index=False)
