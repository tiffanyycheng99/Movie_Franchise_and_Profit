# %%
# Dependencies and Setup
import pandas as pd
import json

# SQL Alchemy Dependencies
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Read movie_metadata.csv into movie_df
movie_df = pd.read_csv("Resources/movie_metadata.csv")
movie_df.rename(columns={'movie_title':'title'}, inplace=True)

# %%
# Read all_script.csv into script_df
script_df = pd.read_csv("Resources/all_script.csv")
script_df
# Out:
#                            title  Swear_Count  Fuck_Count  Shit_Count  \
# 0     10 Things I Hate About You           15           3           6
# 1                             12            2           2           0
# 2                 12 and Holding           21          10          10
# 3                     12 Monkeys           17          11           4
# 4               12 Years a Slave            1           0           0
# ...                          ...          ...         ...         ...
# 1206             You've Got Mail            9           4           4
# 1207             Youth in Revolt            6           2           4
# 1208            Zero Dark Thirty           43          40           2
# 1209                  Zerophilia           18          14           4
# 1210                    Zootopia            0           0           0
#
#       Bitch_Count  Profanity
# 0               6          1
# 1               0          1
# 2               1          1
# 3               2          1
# 4               1          1
# ...           ...        ...
# 1206            1          1
# 1207            0          1
# 1208            1          1
# 1209            0          1
# 1210            0          0
#
# [1211 rows x 6 columns]

# %%
movie_df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# title                         object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# Select
cleaned_movie_df = movie_df[["title","director_name","genres","duration","title_year","budget","content_rating","imdb_score","gross","actor_1_name","actor_2_name","facenumber_in_poster","country"]]
cleaned_movie_df
# Out:
#                                                   title      director_name  \
# 0                                                Avatar      James Cameron
# 1              Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                               Spectre         Sam Mendes
# 3                                 The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                            Signed Sealed Delivered        Scott Smith
# 5039                          The Following                            NaN
# 5040                               A Plague So Pleasant   Benjamin Roberds
# 5041                                   Shanghai Calling        Daniel Hsia
# 5042                                  My Date with Drew           Jon Gunn
#
#                                genres  duration  title_year       budget  \
# 0     Action|Adventure|Fantasy|Sci-Fi     178.0      2009.0  237000000.0
# 1            Action|Adventure|Fantasy     169.0      2007.0  300000000.0
# 2           Action|Adventure|Thriller     148.0      2015.0  245000000.0
# 3                     Action|Thriller     164.0      2012.0  250000000.0
# 4                         Documentary       NaN         NaN          NaN
# ...                               ...       ...         ...          ...
# 5038                     Comedy|Drama      87.0      2013.0          NaN
# 5039     Crime|Drama|Mystery|Thriller      43.0         NaN          NaN
# 5040            Drama|Horror|Thriller      76.0      2013.0       1400.0
# 5041             Comedy|Drama|Romance     100.0      2012.0          NaN
# 5042                      Documentary      90.0      2004.0       1100.0
#
#      content_rating  imdb_score        gross     actor_1_name  \
# 0             PG-13         7.9  760505847.0      CCH Pounder
# 1             PG-13         7.1  309404152.0      Johnny Depp
# 2             PG-13         6.8  200074175.0  Christoph Waltz
# 3             PG-13         8.5  448130642.0        Tom Hardy
# 4               NaN         7.1          NaN      Doug Walker
# ...             ...         ...          ...              ...
# 5038            NaN         7.7          NaN      Eric Mabius
# 5039          TV-14         7.5          NaN      Natalie Zea
# 5040            NaN         6.3          NaN      Eva Boehnke
# 5041          PG-13         6.3      10443.0        Alan Ruck
# 5042             PG         6.6      85222.0      John August
#
#           actor_2_name  facenumber_in_poster country
# 0     Joel David Moore                   0.0     USA
# 1        Orlando Bloom                   0.0     USA
# 2         Rory Kinnear                   1.0      UK
# 3       Christian Bale                   0.0     USA
# 4           Rob Walker                   0.0     NaN
# ...                ...                   ...     ...
# 5038     Daphne Zuniga                   2.0  Canada
# 5039     Valorie Curry                   1.0     USA
# 5040     Maxwell Moody                   0.0     USA
# 5041     Daniel Henney                   5.0     USA
# 5042  Brian Herzlinger                   0.0     USA
#
# [5043 rows x 13 columns]

# %%
cleaned_movie_df.genres = cleaned_movie_df.genres.str.split('|')
# Out:
# C:\Users\tiffa\Anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
cleaned_movie_df['title'].astype("string")
# Out:
# 0                                                  Avatar
# 1                Pirates of the Caribbean: At World's End
# 2                                                 Spectre
# 3                                   The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                              Signed Sealed Delivered
# 5039                            The Following
# 5040                                 A Plague So Pleasant
# 5041                                     Shanghai Calling
# 5042                                    My Date with Drew
# Name: title, Length: 5043, dtype: string

# %%
script_df['title'].astype("string")
# Out:
# 0       10 Things I Hate About You
# 1                               12
# 2                   12 and Holding
# 3                       12 Monkeys
# 4                 12 Years a Slave
#                    ...
# 1206               You've Got Mail
# 1207               Youth in Revolt
# 1208              Zero Dark Thirty
# 1209                    Zerophilia
# 1210                      Zootopia
# Name: title, Length: 1211, dtype: string

# %%
script_df.dtypes
# Out:
# title          object
# Swear_Count     int64
# Fuck_Count      int64
# Shit_Count      int64
# Bitch_Count     int64
# Profanity       int64
# dtype: object

# %%
movie_swear_df = pd.merge(cleaned_movie_df,script_df,how='inner',on='title')
#movie_df.join(script_df, on='title',how='outer')

movie_swear_df
# Out:
#                                           title     director_name  \
# 0                                        Avatar     James Cameron
# 1        Harry Potter and the Half-Blood Prince       David Yates
# 2    Pirates of the Caribbean: Dead Man's Chest    Gore Verbinski
# 3                                Men in Black 3  Barry Sonnenfeld
# 4                                     King Kong     Peter Jackson
# ..                                          ...               ...
# 615                                        Cube   Vincenzo Natali
# 616                                    Swingers        Doug Liman
# 617                                          Pi  Darren Aronofsky
# 618                                      Clerks       Kevin Smith
# 619                                 El Mariachi  Robert Rodriguez
#
#                                             genres  duration  title_year  \
# 0                  Action|Adventure|Fantasy|Sci-Fi     178.0      2009.0
# 1                 Adventure|Family|Fantasy|Mystery     153.0      2009.0
# 2                         Action|Adventure|Fantasy     151.0      2006.0
# 3    Action|Adventure|Comedy|Family|Fantasy|Sci-Fi     106.0      2012.0
# 4                   Action|Adventure|Drama|Romance     201.0      2005.0
# ..                                             ...       ...         ...
# 615                        Mystery|Sci-Fi|Thriller      90.0      1997.0
# 616                                   Comedy|Drama      96.0      1996.0
# 617                         Drama|Mystery|Thriller      84.0      1998.0
# 618                                         Comedy     102.0      1994.0
# 619            Action|Crime|Drama|Romance|Thriller      81.0      1992.0
#
#           budget content_rating  imdb_score        gross     actor_1_name  \
# 0    237000000.0          PG-13         7.9  760505847.0      CCH Pounder
# 1    250000000.0             PG         7.5  301956980.0     Alan Rickman
# 2    225000000.0          PG-13         7.3  423032628.0      Johnny Depp
# 3    225000000.0          PG-13         6.8  179020854.0       Will Smith
# 4    207000000.0          PG-13         7.2  218051260.0      Naomi Watts
# ..           ...            ...         ...          ...              ...
# 615     365000.0              R         7.3     489220.0    David Hewlett
# 616     200000.0              R         7.4    4505922.0      Jon Favreau
# 617      60000.0              R         7.5    3216970.0    Mark Margolis
# 618     230000.0              R         7.8    3151130.0      Jason Mewes
# 619       7000.0              R         6.9    2040920.0  Carlos Gallardo
#
#            actor_2_name  facenumber_in_poster  Swear_Count  Fuck_Count  \
# 0      Joel David Moore                   0.0            8           1
# 1      Daniel Radcliffe                   3.0            0           0
# 2         Orlando Bloom                   2.0            0           0
# 3     Michael Stuhlbarg                   1.0            1           0
# 4    Thomas Kretschmann                   0.0            0           0
# ..                  ...                   ...          ...         ...
# 615     Julian Richings                   0.0           23          23
# 616         Alex Désert                   0.0           22          11
# 617       Clint Mansell                   0.0           11          10
# 618    Brian O'Halloran                   4.0           85          69
# 619     Peter Marquardt                   0.0            0           0
#
#      Shit_Count  Bitch_Count  Profanity
# 0             5            2          1
# 1             0            0          0
# 2             0            0          0
# 3             1            0          1
# 4             0            0          0
# ..          ...          ...        ...
# 615           0            0          1
# 616           8            3          1
# 617           1            0          1
# 618          16            0          1
# 619           0            0          0
#
# [620 rows x 17 columns]

# %%
movie_swear_df.to_csv("Resources/movie_swear.csv")

# %%
# Create database connection and load quake.df into database
rds_connection_string = "postgres:postgres@localhost:5432/movie_swear_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
cleaned_movie_df.to_sql(name='movie',con=engine, if_exists='replace',index=False)

# %%
script_df.to_sql(name='script',con=engine, if_exists='replace',index=False)

# %%
movie_swear_df.to_sql(name='movie_swear',con=engine, if_exists='replace',index=False)
