# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [/Users/kylagelev/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache

# %%
url = 'https://imsdb.com/genre/Thriller'
browser.visit(url)
html = browser.html
    # Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
test=[]
titles=soup.find_all('p')
titles
# titles[0].find('a').text
for title in titles: 
    names=title.find('a').text
    test.append(names)
    


test
# Out:
# ['12 Monkeys',
#  '127 Hours',
#  '15 Minutes',
#  '2012',
#  '48 Hrs.',
#  '8MM',
#  'A Few Good Men',
#  'Absolute Power',
#  'Abyss, The',
#  'Adjustment Bureau, The',
#  'After.Life',
#  'Air Force One',
#  'Alien',
#  'Alien 3',
#  'Alien vs. Predator',
#  'Alien: Resurrection',
#  'Aliens',
#  "All the President's Men",
#  'Alone in the Dark',
#  'American History X',
#  'American Psycho',
#  'American, The',
#  'Angels & Demons',
#  'Anonymous',
#  'Antitrust',
#  'Apt Pupil',
#  'Arbitrage',
#  'Arctic Blue',
#  'Argo',
#  'Armageddon',
#  'Assassins',
#  'Assignment, The',
#  "Avventura, L' (The Adventure)",
#  'Babel',
#  'Backdraft',
#  'Bad Day at Black Rock',
#  'Bad Dreams',
#  'Badlands',
#  'Barton Fink',
#  'Basic',
#  'Basic Instinct',
#  'Batman',
#  'Batman 2',
#  'Batman and Robin',
#  'Batman Begins',
#  'Batman Returns',
#  'Beach, The',
#  'Big Lebowski, The',
#  'Birds, The',
#  'Black Dahlia, The',
#  'Black Swan',
#  'Blade II',
#  'Blade: Trinity',
# ...

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url ='https://imsdb.com/scripts/15-Minutes.html'
browser.visit(url)
# browser.links.find_by_partial_href("scripts").click()
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
script=soup.find("td", class_="scrtext").find('pre')
script_more=soup.find('pre').text.split()

print(script_more)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [/Users/kylagelev/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache
# ...

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = 'https://imsdb.com/Movie%20Scripts/Alien%20vs.%20Predator%20Script.html'
browser.visit(url)
browser.links.find_by_partial_text("Read").click()
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
script=soup.find("td", class_="scrtext").find('pre').text.split()

#script_more=script.find('pre').text.split()

print(script_more)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [/Users/kylagelev/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache
# ...

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = 'https://imsdb.com/genre/Thriller'
browser.visit(url)
script_list=[]
for name in test: 
    try: 
        browser.links.find_by_partial_text(name).click()
        browser.links.find_by_partial_text("Read").click()
        time.sleep(5)
        html = browser.html
            # Parse HTML with Beautiful Soup|
        soup = BeautifulSoup(html, 'html.parser')
        script=soup.find("td", class_="scrtext").find('pre').text.split()
        script_list.append(script)

        browser.links.find_by_partial_text("Thriller").click()
    except: 
        print(f"No Script for: {name}")
        script_list.append("null")
        browser.visit(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [/Users/kylagelev/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache
# No Script for: 12 Monkeys
# No Script for: 127 Hours
# No Script for: 15 Minutes
# No Script for: 2012
# No Script for: 48 Hrs.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-83fc1dfa058d> in <module>
#       7     try:
# ----> 8         browser.links.find_by_partial_text(name).click()
#       9         browser.links.find_by_partial_text("Read").click()
#
# /opt/anaconda3/lib/python3.8/site-packages/splinter/driver/webdriver/__init__.py in click(self)
#     780             try:
# --> 781                 return self._element.click()
#     782             except(
#
# ...

# %%
browser.quit()

# %%
movie_dict=[]

for i in range(len(test)): 
    movie_dict.append({'title':test[i],'Script':script_list[i], 'Swear_Count': []})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-7994aff2d174> in <module>
#       2
#       3 for i in range(len(test)):
# ----> 4     movie_dict.append({'title':test[i],'Script':script_list[i], 'Swear_Count': []})
#
# IndexError: list index out of range

# %%
key_words=['fuck','shit','bitch', 'motherfucker', 'fucked', 'fucking']

Apocolypse_Now=movie_dict[0]    
swear_counter=0
Apcolypse_Now_script=Apocolypse_Now["Script"]

for word in Apcolypse_Now_script: 
    if word in key_words: 
        word_counter+=1
        print(word)
        
swear_counter
# Out:
# shit
# bitch
# shit
# bitch
# fuck
# shit
# shit
# 0
