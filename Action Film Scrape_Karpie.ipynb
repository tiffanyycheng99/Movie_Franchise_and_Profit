# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\Aaron Karpie\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
url = 'https://imsdb.com/genre/War'
browser.visit(url)
html = browser.html
    # Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
test=[]
titles=soup.find_all('p')
titles
# titles[0].find('a').text
for title in titles: 
    names=title.find('a').text
    test.append(names)
    


test
# Out:
# ['Apocalypse Now',
#  'Barry Lyndon',
#  'Battle of Algiers, The',
#  'Beasts of No Nation',
#  'Braveheart',
#  'Cold Mountain',
#  'Coriolanus',
#  'Courage Under Fire',
#  'Deer Hunter, The',
#  'Defiance',
#  'Four Feathers',
#  'From Here to Eternity',
#  'Full Metal Jacket',
#  'Fury',
#  'Hotel Rwanda',
#  'Inglourious Basterds',
#  'Jeux Interdits',
#  'Last of the Mohicans, The',
#  'Last Samurai, The',
#  'Men Who Stare at Goats, The',
#  'Patriot, The',
#  'Pearl Harbor',
#  'Pianist, The',
#  'Platoon',
#  'Saving Private Ryan',
#  "Schindler's List",
#  'Three Kings',
#  'Three Kings (Spoils of War)',
#  'Tropic Thunder',
#  'Troy',
#  'Valkyrie',
#  'War Horse']

# %%
url = 'https://imsdb.com/genre/War'
browser.visit(url)
script_list=[]
for name in test: 
    try: 
        browser.links.find_by_partial_text(name).click()
        browser.links.find_by_partial_text("Script").click()
        html = browser.html
            # Parse HTML with Beautiful Soup|
        soup = BeautifulSoup(html, 'html.parser')
        script=soup.find("td", class_="scrtext").find('pre').text.split()
        script_list.append(script)

        browser.links.find_by_partial_text("War").click()
    except: 
        print(f"No Script for:{name}")
        script_list.append("null")
        browser.visit(url)
# Out:
# No Script for:Barry Lyndon
# No Script for:Battle of Algiers, The
# No Script for:Coriolanus
# No Script for:Courage Under Fire
# No Script for:Full Metal Jacket
# No Script for:Fury
# No Script for:Jeux Interdits
# No Script for:Troy

# %%
movie_dict=[]

for i in range(len(test)): 
    movie_dict.append({'title':test[i],'Script':script_list[i], 'Swear_Count': [], 'Profanity':[]})
movie_dict[30]
# Out:
# {'title': 'Valkyrie',
#  'Script': ['VALKYRIE',
#   'Written',
#   'by',
#   'Christopher',
#   'McQuarrie',
#   '&',
#   'Nathan',
#   'Alexander',
#   'January',
#   '8,',
#   '2007',
#   'I',
#   'swear',
#   'by',
#   'God',
#   'this',
#   'sacred',
#   'oath:',
#   'That',
#   'I',
#   'shall',
#   'render',
#   'unconditional',
#   'obedience',
#   'to',
#   'Adolf',
#   'Hitler,',
#   'the',
#   'F�hrer',
#   'of',
#   'the',
#   'German',
#   'Reich,',
#   'and',
#   'that',
#   'I',
#   'shall',
#   'at',
#   'all',
#   'times',
#   'be',
#   'prepared,',
#   'as',
#   'a',
#   'brave',
#   'soldier,',
#   'to',
#   'give',
#   'my',
#   'life',
#   'for',
#   'this',
#   'oath.',
#   '1',
#   'BLACK',
#   '1',
#   'And',
#   'from',
#   'out',
#   'of',
#   'the',
#   'blackness',
#   'a',
#   'voice.',
#   'A',
#   'man',
#   'speaking',
#   'in',
#   'German',
#   '-',
#   'faint',
#   'at',
#   'first,',
#   'crackling',
#   'over',
#   'the',
#   'radio.',
#   'Subtitles',
#   'translate',
#   'the',
#   'voice',
#   'of',
#   'Adolf',
#   'Hitler.',
#   'HITLER',
#   '(V.O.)',
#   'My',
#   'comrades.',
#   'Once',
#   'again',
#   '-',
#   'I',
#   "don't",
#   'know',
#   'how',
#   'many',
#   'times',
#   'it',
#   'has',
#   'been',
#   'now',
#   '-',
#   'an',
#   'attempt',
#   'has',
#   'been',
#   'made',
#   'on',
#   'my',
#   'life.',
#   'I',
#   'speak',
#   'to',
#   'you',
#   'tonight',
#   'for',
#   'two',
#   'reasons.',
#   'First,',
#   'so',
#   'that',
#   'you',
#   'can',
#   'hear',
#   'my',
#   'voice',
#   'and',
#   'know',
#   'that',
#   'I',
#   'am',
#   'unhurt.',
#   'And',
#   'second,',
#   'so',
#   'that',
#   'you',
#   'may',
#   'know',
#   'the',
#   'details',
#   'of',
#   'a',
#   'crime',
#   'without',
#   'parallel',
#   'in',
#   'German',
#   'history...',
#   '2',
#   'EXT.',
#   'AIRFIELD',
#   '-',
#   'DAY',
#   '2',
#   'TITLES:',
#   'SMOLENSK,',
#   'RUSSIA',
#   '-',
#   'THE',
#   'GERMAN',
#   'EASTERN',
#   'FRONT.',
#   '13',
#   'MARCH',
#   '1943.',
#   'A',
#   'lonely',
#   'airfield.',
#   'A',
#   'NAZI',
#   'OFFICER',
#   'and',
#   'his',
#   'AIDE',
#   'stand',
#   'rigid',
#   'by',
#   'a',
#   'gleaming',
#   'limousine.',
#   'The',
#   "officer's",
#   'uniform',
#   'denotes',
#   'a',
#   'man',
#   'of',
#   'high',
#   'rank',
#   '-',
#   'a',
#   'man',
#   'of',
#   'weight.',
#   'TITLES:',
#   'MAJOR-GENERAL',
#   'HENNING',
#   'VON',
#   'TRESCKOW',
#   '-',
#   'CHIEF',
#   'OF',
#   'STAFF',
#   'FOR',
#   'ARMY',
#   'GROUP',
#   'CENTER.',
#   'Tresckow',
#   'smokes',
#   'a',
#   'cigarette,',
#   'his',
#   'arm',
#   'the',
#   'only',
#   'movement',
#   'in',
#   'the',
#   'frame.',
#   'PULL',
#   'BACK',
#   'TO',
#   'REVEAL',
#   'the',
#   'airstrip',
#   'is',
#   'surrounded',
#   'by',
#   'Army',
#   'Group',
#   'vehicles',
#   'and',
#   'personnel',
#   '-',
#   'SD',
#   'and',
#   'SS',
#   'escorts,',
#   'photographers,',
#   'aides,',
#   'Nazi',
#   'party',
#   'dignitaries,',
#   'etc.',
#   '-',
#   'all',
#   'frozen',
#   'like',
#   'statues.',
#   'Eerie.',
#   'Whatever',
#   'is',
#   'going',
#   'on,',
#   "it's",
#   'big.',
#   'The',
#   'faint',
#   'sound',
#   'of',
#   'distant',
#   'airplanes',
#   'brings',
#   'tension,',
#   'subtle',
#   'but',
#   'sharp.',
#   'Approaching',
#   'the',
#   'field',
#   'are',
#   'three',
#   'Focke-Wulf',
#   '200',
#   'Condors',
#   'escorted',
#   'by',
#   'a',
#   'formation',
#   'of',
#   'Messerschmitt-109',
#   'fighters.',
#   'Silence',
#   'gives',
#   'way',
#   'to',
#   'an',
#   'escalating',
#   'roar',
#   'that',
#   'seems',
#   'to',
#   'have',
#   'no',
#   'maximum.',
#   'One',
#   'by',
#   'one,',
#   'the',
#   'massive',
#   'four-engine',
#   'Condors',
#   'land',
#   'while',
#   'the',
#   'fighters',
#   'roar',
#   'overhead',
#   'and',
#   'circle',
#   'the',
#   'airfield.',
#   'The',
#   'Condors',
#   'come',
#   'to',
#   'rest',
#   'and,',
#   'needing',
#   'no',
#   'introduction:',
#   'ADOLF',
#   'HITLER',
#   'alights',
#   'from',
#   'the',
#   'lead',
#   'plane,',
#   'obscured',
#   'by',
#   'the',
#   'surrounding',
#   'platoon',
#   'of',
#   'heavily',
#   'armed',
#   'SS',
#   'GUARDS.',
#   '(Note:',
#   'Hitler',
#   'is',
#   'obscured',
#   'throughout',
#   'the',
#   'entire',
#   'sequence',
#   'proving',
#   'how',
#   'inaccessible',
#   'he',
#   'truly',
#   'was.)',
#   '2.',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide',
#   'step',
#   'forward',
#   'to',
#   'greet',
#   'Hitler,',
#   'but',
#   'they',
#   'are',
#   'pushed',
#   'back',
#   'by',
#   'SS',
#   'guards.',
#   'The',
#   'F�hrer',
#   'marches',
#   'past',
#   'without',
#   'so',
#   'much',
#   'a',
#   'glance',
#   'at',
#   'his',
#   'hosts',
#   'or',
#   'their',
#   'waiting',
#   'limo.',
#   'To',
#   "Tresckow's",
#   'surprise,',
#   'a',
#   'second',
#   'limousine',
#   'roars',
#   'onto',
#   'the',
#   'airfield',
#   'from',
#   'out',
#   'of',
#   'nowhere.',
#   'It',
#   'is',
#   'dirty,',
#   'the',
#   'windscreen',
#   'spotted',
#   'with',
#   'bugs',
#   'from',
#   'a',
#   'long',
#   'drive.',
#   'Hitler',
#   'gets',
#   'in',
#   'the',
#   'dirty',
#   'car',
#   'and',
#   'speeds',
#   'off.',
#   'VOICE',
#   '(O.S.)',
#   "It's",
#   'not',
#   'so',
#   'much',
#   'your',
#   'car',
#   'he',
#   "doesn't",
#   'trust...',
#   "It's",
#   'your',
#   'driver.',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide',
#   'turn.',
#   'Standing',
#   'behind',
#   'them',
#   'is:',
#   'TITLES:',
#   'COLONEL',
#   'HEINZ',
#   'BRANDT',
#   '-',
#   'SENIOR',
#   'STAFF',
#   'OFFICER',
#   'OF',
#   'THE',
#   'ARMY',
#   'OPERATIONS',
#   'SECTION.',
#   'The',
#   'consummate',
#   'Nazi,',
#   'he',
#   'is',
#   'always',
#   'scribbling',
#   'notes',
#   'in',
#   'a',
#   'small',
#   'datebook.',
#   'Without',
#   'looking',
#   'up,',
#   'Brandt',
#   'hops',
#   'into',
#   'the',
#   'limo',
#   'they',
#   'brought',
#   'for',
#   'Hitler.',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide',
#   'share',
#   'a',
#   'glance',
#   'and',
#   'get',
#   'in.',
#   'A',
#   'beat',
#   'later',
#   'they',
#   'are',
#   'speeding',
#   'after',
#   "Hitler's",
#   'car.',
#   '3',
#   'EXT.',
#   'ARMY',
#   'GROUP',
#   'CENTER',
#   '-',
#   'DAY',
#   '3',
#   'Est.',
#   "Hitler's",
#   'headquarters',
#   'for',
#   'the',
#   'Eastern',
#   'Front',
#   'is',
#   'bustling.',
#   'Security',
#   'is',
#   'tight,',
#   'everyone',
#   'is',
#   'on',
#   'edge.',
#   '4',
#   'INT.',
#   'ARMY',
#   'GROUP',
#   'CENTER',
#   '-',
#   'MESS',
#   'HALL',
#   '-',
#   'DAY',
#   '4',
#   'Long',
#   'tables',
#   'packed',
#   'with',
#   'SOLDIERS',
#   'straining',
#   'their',
#   'necks',
#   'to',
#   'get',
#   'a',
#   'glimpse',
#   'of',
#   'their',
#   'leader',
#   'at',
#   'the',
#   'head',
#   'table,',
#   'but',
#   'he',
#   'is',
#   'obscured',
#   'by',
#   'his',
#   'detail',
#   'of',
#   'SS',
#   'guards.',
#   'ONE',
#   'MAN',
#   'dares',
#   'to',
#   'approach.',
#   'The',
#   'room',
#   'falls',
#   'silent.',
#   "HITLER'S",
#   'PERSONAL',
#   'CHEF',
#   'places',
#   'a',
#   'tray',
#   'before',
#   'the',
#   'F�hrer,',
#   'producing',
#   'a',
#   'knife',
#   'and',
#   'fork,',
#   'cutting',
#   'a',
#   'bite.',
#   'We',
#   'think',
#   'he',
#   'is',
#   'going',
#   'to',
#   'hand',
#   'feed',
#   'Hitler',
#   'until',
#   'he',
#   'places',
#   'the',
#   'food',
#   'in',
#   'his',
#   'own',
#   'mouth,',
#   'chewing',
#   'slowly,',
#   'deliberately.',
#   'He',
#   'swallows.',
#   'We',
#   'wait',
#   'for',
#   'him',
#   'to',
#   'die.',
#   'When',
#   'he',
#   "doesn't,",
#   'Hitler',
#   'begins',
#   'to',
#   'eat.',
#   'The',
#   'rest',
#   'of',
#   'the',
#   'room',
#   'relaxes',
#   'slightly',
#   'and',
#   'digs',
#   'in.',
#   'ANGLE',
#   'ON:',
#   'Seated',
#   'further',
#   'down',
#   'the',
#   'table',
#   'are',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide.',
#   'Between',
#   'them,',
#   'once',
#   'again,',
#   'is',
#   'Brandt,',
#   'eating',
#   'like',
#   'a',
#   'pig,',
#   'still',
#   'making',
#   'notes',
#   'in',
#   'his',
#   'book.',
#   'Tresckow',
#   'stares.',
#   '3.',
#   'TRESCKOW',
#   'Managing',
#   'the',
#   "F�hrer's",
#   'security',
#   'must',
#   'be',
#   'quite',
#   'an',
#   'undertaking.',
#   'BRANDT',
#   '(in',
#   'between',
#   'mouthfuls)',
#   'Irregularity',
#   'is',
#   'the',
#   "F�hrer's",
#   'precaution',
#   'of',
#   'choice.',
#   'TRESCKOW',
#   'I',
#   'can',
#   'assure',
#   'you',
#   "he's",
#   'safe',
#   'here.',
#   'Relax,',
#   'Brandt.',
#   'Enjoy',
#   'your',
#   'meal.',
#   "Brandt's",
#   'look',
#   'says,',
#   '"Don\'t',
#   'be',
#   'ridiculous."',
#   'He',
#   'cleans',
#   'his',
#   'plate',
#   'in',
#   'seconds.',
#   'Then',
#   'he',
#   'gently',
#   'dabs',
#   'his',
#   'mouth,',
#   'takes',
#   'out',
#   'his',
#   'datebook',
#   'and',
#   'starts',
#   'writing',
#   '-',
#   'once',
#   'again',
#   'the',
#   'precise',
#   'man',
#   'we',
#   'saw',
#   'on',
#   'the',
#   'airfield.',
#   'TRESCKOW',
#   "(CONT'D)",
#   'I',
#   'understand',
#   "you're",
#   'returning',
#   'to',
#   'Berlin',
#   'this',
#   'afternoon...',
#   'Brandt',
#   'nods.',
#   'TRESCKOW',
#   "(CONT'D)",
#   'Could',
#   'I',
#   'trouble',
#   'you',
#   'to',
#   'deliver',
#   'a',
#   'package',
#   'to',
#   'Colonel',
#   'Stieff?',
#   'Brandt',
#   'nods',
#   'again,',
#   'too',
#   'busy',
#   'writing',
#   'to',
#   'notice',
#   'the',
#   'knowing',
#   'glance',
#   'Tresckow',
#   'shares',
#   'with',
#   'his',
#   'Aide...',
#   '5',
#   'INT.',
#   'ARMY',
#   'GROUP',
#   'CENTER',
#   '-',
#   'PRIVATE',
#   'OFFICE',
#   '-',
#   'LATER',
#   '5',
#   'Tense',
#   'silence.',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide',
#   'are',
#   'hunched',
#   'over',
#   'two',
#   'bottles',
#   'of',
#   'Cointreau',
#   'on',
#   'a',
#   'large',
#   'desk',
#   'next',
#   'to:',
#   'TWO',
#   'PAIRS',
#   'OF',
#   'BRITISH',
#   "`CLAMS'",
#   '-',
#   'a',
#   'small',
#   'black',
#   'plastic',
#   'casing',
#   'held',
#   'together',
#   'by',
#   'magnets',
#   'and',
#   'adhesive',
#   'tape.',
#   'Tresckow',
#   'inserts',
#   'a',
#   'short,',
#   'pencil-shaped',
#   'fuse',
#   'through',
#   'the',
#   'narrow',
#   'opening.',
#   'All',
#   'that',
#   'remains',
#   'exposed',
#   'is',
#   'a',
#   'small',
#   'glass',
#   'capsule.',
#   'The',
#   'trigger.',
#   'Tresckow',
#   'turns',
#   'his',
#   'attention',
#   'to',
#   'the',
#   'bottles',
#   'of',
#   'Cointreau...',
#   '6',
#   'EXT.',
#   'AIRFIELD',
#   '-',
#   'DAY',
#   '6',
#   'The',
#   "Condors'",
#   'engines',
#   'roar,',
#   'ready',
#   'for',
#   'take',
#   'off.',
#   'Soldiers',
#   'stand',
#   'at',
#   'attention',
#   'as',
#   'Hitler',
#   'boards.',
#   'Brandt',
#   'is',
#   'with',
#   'him,',
#   'scribbling',
#   'in',
#   'his',
#   'ever-present',
#   'datebook.',
#   '4.',
#   'Tresckow',
#   'and',
#   'his',
#   'Aide',
#   'approach.',
#   'Tresckow',
#   'gently',
#   'handles',
#   'a',
#   'carefully',
#   'wrapped',
#   'package.',
#   'CLOSE',
#   'ON:',
#   'Tresckow',
#   'presses',
#   'a',
#   'key',
#   'against',
#   'the',
#   'side',
#   'of',
#   'the',
#   'package,',
#   'crushing',
#   'the',
#   'glass',
#   'capsule',
#   'inside.',
#   'The',
#   'explosive',
#   'armed',
#   'now,',
#   'he',
#   'hands',
#   'it',
#   'to',
#   'Brandt.',
#   'TRESCKOW',
#   'With',
#   'my',
#   'regards',
#   'to',
#   'Colonel',
#   'Stieff.',
#   'Brandt',
#   'accepts',
#   'the',
#   'gift,',
#   'looking',
#   'up',
#   'from',
#   'his',
#   'book.',
#   'He',
#   'studies',
#   'the',
#   'familiar',
#   'shape.',
#   'BRANDT',
#   'Cointreau?',
#   'You',
#   'better',
#   'hope',
#   'I',
#   "don't",
#   'get',
#   'thirsty',
#   'on',
#   'the',
#   'flight.',
#   'Tresckow',
#   'politely',
#   'smiles,',
#   'hiding',
#   'his',
#   'nerves,',
#   'having',
#   'just',
#   'handed',
#   'a',
#   'bomb',
#   'to',
#   "Hitler's",
#   'Head',
#   'of',
#   'Security.',
#   'Brandt',
#   'unknowingly',
#   'carries',
#   'it',
#   'onto',
#   'the',
#   'plane',
#   'with',
#   'Hitler.',
#   'The',
#   'door',
#   'to',
#   'the',
#   'Condor',
#   'is',
#   'sealed',
#   'behind',
#   'him',
#   'along',
#   'with,',
#   'we',
#   'hope,',
#   'the',
#   "F�hrer's",
#   'fate.',
#   ...],
#  'Swear_Count': [],
#  'Profanity': []}

# %%
key_words=['fuck', 'shit','bitch']


fuck_counter=0
shit_counter=0
bitch_counter=0
mother_fucking_counter=0

for i in range(len(movie_dict)): 
    
    movie_key=movie_dict[i]
    print(f"we are at:{movie_key['title']}")
    movie_script=movie_key["Script"]
    
    for word in movie_script: 
        
        if word in key_words: 
            if word=='fuck': 
                fuck_counter+=1
            elif word=='shit': 
                shit_counter+=1
            elif word=='bitch':
                bitch_counter+=1
            

    print(movie_key['title'])

    print(f"The number of times fuck is said:{fuck_counter}")
    print(f"The number of times shit is said:{shit_counter}")
    print(f"The number of times bitch is said:{bitch_counter}")

    swear_counter=fuck_counter+shit_counter+bitch_counter
    print(f'Profanity Total:{swear_counter}')

print(swear_counter)
# Out:
# we are at:Apocalypse Now
# Apocalypse Now
# The number of times fuck is said:1
# The number of times shit is said:4
# The number of times bitch is said:2
# Profanity Total:7
# we are at:Barry Lyndon
# Barry Lyndon
# The number of times fuck is said:1
# The number of times shit is said:4
# The number of times bitch is said:2
# Profanity Total:7
# we are at:Battle of Algiers, The
# Battle of Algiers, The
# The number of times fuck is said:1
# The number of times shit is said:4
# The number of times bitch is said:2
# Profanity Total:7
# we are at:Beasts of No Nation
# Beasts of No Nation
# The number of times fuck is said:1
# The number of times shit is said:4
# The number of times bitch is said:2
# Profanity Total:7
# we are at:Braveheart
# Braveheart
# The number of times fuck is said:1
# The number of times shit is said:4
# The number of times bitch is said:2
# Profanity Total:7
# we are at:Cold Mountain
# Cold Mountain
# The number of times fuck is said:1
# The number of times shit is said:8
# The number of times bitch is said:2
# Profanity Total:11
# we are at:Coriolanus
# Coriolanus
# The number of times fuck is said:1
# The number of times shit is said:8
# The number of times bitch is said:2
# Profanity Total:11
# we are at:Courage Under Fire
# Courage Under Fire
# The number of times fuck is said:1
# The number of times shit is said:8
# The number of times bitch is said:2
# Profanity Total:11
# we are at:Deer Hunter, The
# Deer Hunter, The
# The number of times fuck is said:6
# The number of times shit is said:10
# The number of times bitch is said:2
# Profanity Total:18
# we are at:Defiance
# Defiance
# The number of times fuck is said:6
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:26
# we are at:Four Feathers
# Four Feathers
# The number of times fuck is said:6
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:26
# we are at:From Here to Eternity
# From Here to Eternity
# The number of times fuck is said:6
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:26
# we are at:Full Metal Jacket
# Full Metal Jacket
# The number of times fuck is said:6
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:26
# we are at:Fury
# Fury
# The number of times fuck is said:6
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:26
# we are at:Hotel Rwanda
# Hotel Rwanda
# The number of times fuck is said:8
# The number of times shit is said:18
# The number of times bitch is said:2
# Profanity Total:28
# we are at:Inglourious Basterds
# Inglourious Basterds
# The number of times fuck is said:17
# The number of times shit is said:19
# The number of times bitch is said:3
# Profanity Total:39
# we are at:Jeux Interdits
# Jeux Interdits
# The number of times fuck is said:17
# The number of times shit is said:19
# The number of times bitch is said:3
# Profanity Total:39
# we are at:Last of the Mohicans, The
# Last of the Mohicans, The
# The number of times fuck is said:17
# The number of times shit is said:19
# The number of times bitch is said:3
# Profanity Total:39
# we are at:Last Samurai, The
# Last Samurai, The
# The number of times fuck is said:17
# The number of times shit is said:20
# The number of times bitch is said:3
# Profanity Total:40
# we are at:Men Who Stare at Goats, The
# Men Who Stare at Goats, The
# The number of times fuck is said:19
# The number of times shit is said:20
# The number of times bitch is said:3
# Profanity Total:42
# we are at:Patriot, The
# Patriot, The
# The number of times fuck is said:19
# The number of times shit is said:20
# The number of times bitch is said:3
# Profanity Total:42
# we are at:Pearl Harbor
# Pearl Harbor
# The number of times fuck is said:23
# The number of times shit is said:28
# The number of times bitch is said:5
# Profanity Total:56
# we are at:Pianist, The
# Pianist, The
# The number of times fuck is said:24
# The number of times shit is said:29
# The number of times bitch is said:5
# Profanity Total:58
# we are at:Platoon
# Platoon
# The number of times fuck is said:43
# The number of times shit is said:62
# The number of times bitch is said:8
# Profanity Total:113
# we are at:Saving Private Ryan
# Saving Private Ryan
# The number of times fuck is said:50
# The number of times shit is said:65
# The number of times bitch is said:8
# Profanity Total:123
# we are at:Schindler's List
# Schindler's List
# The number of times fuck is said:51
# The number of times shit is said:65
# The number of times bitch is said:8
# Profanity Total:124
# we are at:Three Kings
# Three Kings
# The number of times fuck is said:63
# The number of times shit is said:73
# The number of times bitch is said:8
# Profanity Total:144
# we are at:Three Kings (Spoils of War)
# Three Kings (Spoils of War)
# The number of times fuck is said:64
# The number of times shit is said:74
# The number of times bitch is said:9
# Profanity Total:147
# we are at:Tropic Thunder
# Tropic Thunder
# The number of times fuck is said:72
# The number of times shit is said:80
# The number of times bitch is said:10
# Profanity Total:162
# we are at:Troy
# Troy
# The number of times fuck is said:72
# The number of times shit is said:80
# The number of times bitch is said:10
# Profanity Total:162
# we are at:Valkyrie
# Valkyrie
# The number of times fuck is said:72
# The number of times shit is said:81
# The number of times bitch is said:10
# Profanity Total:163
# we are at:War Horse
# War Horse
# The number of times fuck is said:72
# The number of times shit is said:81
# The number of times bitch is said:10
# Profanity Total:163
# 163

# %%
key_words=['fuck', 'shit','bitch']

Apocolypse_Now=movie_dict[1]  
fuck_counter=0
shit_counter=0
bitch_counter=0
mother_fucking_counter=0
Apcolypse_Now_script=Apocolypse_Now["Script"]

for word in Apcolypse_Now_script: 
    if word in key_words: 
        if word=='fuck': 
            fuck_counter+=1
        elif word=='shit': 
            shit_counter+=1
        elif word=='bitch':
            bitch_counter+=1
        else: 
            mother_fucking_counter+=1  

print(f"The number of times fuck is said:{fuck_counter}")
print(f"The number of times shit is said:{shit_counter}")
print(f"The number of times bitch is said:{bitch_counter}")
# Out:
# The number of times fuck is said:0
# The number of times shit is said:0
# The number of times bitch is said:0
